# %%
#Import opencv for computer vision stuff
import cv2
# Import matplotlib so we can visualize an image
from matplotlib import pyplot as plt

# %%
# Connect to capture device
cap = cv2.VideoCapture(0)

# %%
# Get a frame from the capture device
ret, frame = cap.read()

# %%
print(ret)
# Out:
# True

# %%
plt.imshow(frame)

# %%
# releases capture back into the wild
cap.release()

# %%
# Function to take photo from webcam
def take_photo():
    cap = cv2.VideoCapture(0)
    ret, frame = cap.read()
    cv2.imwrite('webcamphoto.jpg', frame)
    cap.release()

# %%
take_photo()

# %%
# Connect to webcam
cap = cv2.VideoCapture(0)
# Loop through every frame until we close our webcam
while True():
    ret, frame = cap.read()

    # Show image
    cv2.imshow('Webcam', frame)
    
    # Checks whether q has been hit and stops the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# <>:4: SyntaxWarning: 'bool' object is not callable; perhaps you missed a comma?
# <>:4: SyntaxWarning: 'bool' object is not callable; perhaps you missed a comma?
# /var/folders/0c/kng0997d3kgbhly23wgywqwm0000gn/T/ipykernel_43625/3478739994.py:4: SyntaxWarning: 'bool' object is not callable; perhaps you missed a comma?
#   while True():
# /var/folders/0c/kng0997d3kgbhly23wgywqwm0000gn/T/ipykernel_43625/3478739994.py:4: SyntaxWarning: 'bool' object is not callable; perhaps you missed a comma?
#   while True():
# /var/folders/0c/kng0997d3kgbhly23wgywqwm0000gn/T/ipykernel_43625/3478739994.py:4: SyntaxWarning: 'bool' object is not callable; perhaps you missed a comma?
#   while True():
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 cap = cv2.VideoCapture(0)
#       3 # Loop through every frame until we close our webcam
# ----> 4 while True():
#       5     ret, frame = cap.read()
#       7     # Show image
#
# TypeError: 'bool' object is not callable

# %%
cap = cv2.VideoCapture(0)

# %%
cap.isOpened()
# Out:
# True

# %%
cap.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cap.release()
#
# NameError: name 'cap' is not defined
